# %%
#imports
import csv
import requests
from datetime import datetime
from bs4 import BeautifulSoup

#url
def get_url(position, location,page_start):
    """(Specifically for se.Indeed.com)Generate a url from position and location on which page to start"""
    template = 'https://se.indeed.com/jobs?q={}&l={}&start={}'
    #Starting with the template var, use string formatting to pass in the position and location
    #and format it to the var url. Don't need worry about formatting the url with %20 or + signs to fill in spaces, 
    #the request will interpret correctly without them on this website, however don't include and punctuation or chars not typically used in a url.
    url = template.format(position, location,(page_start-1)*10)
    return url

def web_scrape(position, location,pages):
    """(Specifically for se.Indeed.com)"""
    global current_page                            # If captcha stops scraping, current_page keeps track of page number
    front_page_url =get_url(position, location,current_page)  
    front_page_response = requests.get(front_page_url)                   
    front_page_html = BeautifulSoup(front_page_response.text, 'html.parser') #BeautifulSoup returns the HTML code of the page
    atag_list = front_page_html.find_all('a',{'data-hiring-event': 'false'}) #Magically returns the html responsible for job posts
    data_rows = []
    captcha_exit = False
    while current_page <= pages:
        print('Page: ' + current_page)
        for atag in atag_list:
            print('\n')
            #For each job post(atag), got to that page and save the title and requirements as a row in data_rows  
            print('href: ' + atag.get('href'))
            job_url = 'https://se.indeed.com' + atag.get('href')   # go to the atag link
            job_page_response = requests.get(job_url)  
            job_html = BeautifulSoup(job_page_response.text, 'html.parser')  #Read the page's Html
            
            #If captcha stops our request.get, the code below will return an Attribute error.
            try:
                title = job_html.head.title.get_text(strip=True)
                print("title = " +title)
                if position in title.lower(): # Better to have accurate data than false positives
                    div_list = job_html.find('div', class_='jobsearch-jobDescriptionText')
                    
                    #After inspecting patterns at Indeed, (unordered list -> list) best way to find requirements
                    #It will sometimes not return anything, but if it returns anything, it often is the desired info.
                    requirements = ' '.join([div_list.select('ul > li')[x].get_text(strip=True) for x in range(len(div_list.select('ul > li')))])
                    
                    if requirements != '':
                        data_rows.append([title,requirements])
            except AttributeError:
                captcha_exit = True
                print(AttributeError)
                break
                
        if captcha_exit == True:
            break
        try: #Go back to front page and click on the next page button.
            next_page_url = 'https://se.indeed.com' + front_page_html.find('a',{'aria-label': 'Nästa'}).get('href')
            next_page_response = requests.get(next_page_url,headers={'User-Agent': 'Mozilla/5.0'})  
            next_page_html = BeautifulSoup(next_page_response.text, 'html.parser')
            atag_list = next_page_html.find_all('a',{'data-hiring-event': 'false'})#Replace atag_list to repeat for next page
            front_page_html = next_page_html
            current_page += 1
        except AttributeError:
            print(AttributeError)
            break
        
    #Writing data_rows to a csv file.
    today = datetime.today().strftime('%Y-%m-%d')
    with open('_'.join(position.split(' ')) + '_' + today + '.csv','a',newline='',encoding="utf-8", errors='replace') as f:
        writer = csv.writer(f)
        writer.writerow(['title', 'requirements'])
        writer.writerows(data_rows)
    return data_rows



import pyautogui
from time import sleep
#To bypass captcha, download desired VPN and switch vpn automatically when captcha stops the scraping process
def connect_to_vpn(vpn_button_x,vpn_button_y):
    pyautogui.click(vpn_button_x, vpn_button_y)
    pyautogui.click(vpn_button_x, vpn_button_y)
def run_cell(cell_x,cell_y):
    pyautogui.click(cell_x, cell_y)
    pyautogui.click(cell_x, cell_y)
    pyautogui.hotkey('ctrl',"enter")
    
#Initialize the positions of vpn button and jupyter cell position
def init():
    global vpn_button_x
    global vpn_button_y
    global cell_x
    global cell_y
    print('Put your mouse over the vpn connect button')
    sleep(1)
    print('3..')
    sleep(1)
    print('2..')
    sleep(1)
    print('1..')
    sleep(1)
    print('VPN connect button position:')
    print(pyautogui.position())
    vpn_button_x, vpn_button_y = pyautogui.position()
    print('Put your mouse over this cell that runs the main script')
    sleep(1)
    print('3..')
    sleep(1)
    print('2..')
    sleep(1)
    print('1..')
    sleep(1)
    print('Cell position:')
    print(pyautogui.position())
    cell_x, cell_y = pyautogui.position() 
    
def main(position,location,pages_to_scrape = 20, auto_repeat = True):
    global current_page #For when captcha stops the scraping
       
    try:
        current_page
    except NameError:
        current_page = 1
    parse_list = web_scrape(position, location,pages_to_scrape)
    if auto_repeat == True:
        if current_page <= pages_to_scrape:
            global vpn_button_x
            global vpn_button_y
            global cell_x
            global cell_y
            connect_to_vpn(vpn_button_x,vpn_button_y)
            sleep(5)
            run_cell(cell_x,cell_y)

# %%
global current_page
current_page = 1
init()
# Out:
# Put your mouse over the vpn connect button
# 3..
# 2..
# 1..
# VPN connect button position:
# Point(x=263, y=399)
# Put your mouse over this cell that runs the main script
# 3..
# 2..
# 1..
# Cell position:
# Point(x=1064, y=714)

# %%
main('backend','sweden',120,True)
# Out:
# 60
#
#
# /rc/clk?jk=9ecc0130d3d305e7&fccid=c3c8df96df173714&vjs=3
# title = Senior Java Developer with AWS experience - 411 03 Göteborg - Indeed.com
#
#
# /rc/clk?jk=ad2c3790e3e0cff6&fccid=377ff150a39aeb0a&vjs=3
# title = Systemutvecklare till Gävle-Dalarna - 784 33 Borlänge - Indeed.com
#
#
# /rc/clk?jk=38ec7525bc00521d&fccid=f452ff89851e4578&vjs=3
# title = Full stack GoLang-utvecklare - Göteborg - Indeed.com
#
#
# /rc/clk?jk=e1fcc336324c8018&fccid=ed21d9e9151873ed&vjs=3
# title = Senior utvecklare - Falun - Indeed.com
#
#
# /rc/clk?jk=5d151a84785a1caf&fccid=6e45afc8910cab9e&vjs=3
# title = Senior Software Engineer - Stockholm - Indeed.com
#
#
# /rc/clk?jk=0885a56e29043c66&fccid=fa0ca3b638673d62&vjs=3
# title = Java Developer, Stockholm - Solna - Indeed.com
#
#
# /rc/clk?jk=bf60686669e75e83&fccid=f8b265243da9f9d7&vjs=3
# title = Backend Developer to ADB Safegate - Malmö kommun - Indeed.com
# im in
#
#
# /rc/clk?jk=56c71f123ed7f46d&fccid=79355ba9d85aec2a&vjs=3
# title = Senior backend Engineer (Java/Kotlin/AWS) - Build brand... - 111 52 Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=cd6541b2bc0be958&fccid=499228cdab2aac2f&vjs=3
# title = Front-end Developer - 102 23 Stockholm - Indeed.com
#
#
# /rc/clk?jk=d9438d2edb33d69c&fccid=7b11f68f7c494ce7&vjs=3
# title = Senior Software Developer - Tradera - 111 22 Stockholm - Indeed.com
#
#
# /rc/clk?jk=80e0eb84fcd2c3ab&fccid=c3c8df96df173714&vjs=3
# title = QA Automation Engineer - 113 31 Stockholm - Indeed.com
#
#
# /rc/clk?jk=c98353179aaf3b24&fccid=3c2ccf5f57192b72&vjs=3
# title = Fullstack-utvecklare - 118 20 Stockholm - Indeed.com
#
#
# /rc/clk?jk=7bcc7cd6c0820f90&fccid=be8d54a0de9f3db0&vjs=3
# title = Software Developer, CloudOps - 431 37 Mölndal - Indeed.com
#
#
# /rc/clk?jk=2006b4cb62022a66&fccid=f19e807a47f00f90&vjs=3
# title = Fullstack Developer - Stockholm - Indeed.com
#
#
# /rc/clk?jk=ef293b837f7e5307&fccid=cadcae9e8089792b&vjs=3
# title = Senior Backend Developer - Plataforma (FTC 6 months) - Stockholm - Indeed.com
# im in
# https://se.indeed.com/jobs?q=backend&l=sweden&start=600
# 61
#
#
# /rc/clk?jk=ef293b837f7e5307&fccid=cadcae9e8089792b&vjs=3
# title = Senior Backend Developer - Plataforma (FTC 6 months) - Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=9fa58709b6b47cbd&fccid=f2d3c39a61984625&vjs=3
# title = Backend Functional Developer, Relay - eCT - 120 30 Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=0bc9b8974346b330&fccid=86489c3786a730f8&vjs=3
# title = Python developer! - 171 54 Solna - Indeed.com
#
#
# /rc/clk?jk=84b4a92d476c6f8e&fccid=0f70dd1b987489a8&vjs=3
# title = Systems Programmer - 118 27 Stockholm - Indeed.com
#
#
# /rc/clk?jk=c0136d3274e24018&fccid=105ecfd0283f415f&vjs=3
# title = Solutions Architect - Helsingborg - Indeed.com
#
#
# /rc/clk?jk=f8ff3661f26cf051&fccid=76dd37756e3d1f10&vjs=3
# title = Frontend Developer - Box - 113 43 Stockholm - Indeed.com
#
#
# /rc/clk?jk=7fc220be5d62a6b5&fccid=29c9cf7db69ee5f9&vjs=3
# title = Mobile App Developer - 412 85 Göteborg - Indeed.com
#
#
# /rc/clk?jk=171c4b54b9486b13&fccid=4c5112fc0b2f3c84&vjs=3
# title = Web Front-end - Editor team - 118 27 Stockholm - Indeed.com
#
#
# /rc/clk?jk=54790ddd93869b66&fccid=3faca64bc2560080&vjs=3
# title = Backend utvecklare intresserad av att utveckla framtidens astmavård? - Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=83ddfbb9b9098d8a&fccid=e309055190d7460e&vjs=3
# title = Backend Developer - Malmö - Indeed.com
# im in
#
#
# /rc/clk?jk=3b10fc6a3fcb7fdb&fccid=ddbb20bc2a34c637&vjs=3
# title = iOS developer with experience of connection to external... - 113 30 Stockholm - Indeed.com
#
#
# /company/Incopro-Ltd./jobs/Software-Engineer-d8a91c47f563618a?fccid=be7c5833d07e8ffc&vjs=3
# title = Software Engineer - React / TypeScript - Jobba hemifrån - Indeed.com
#
#
# /rc/clk?jk=d0e6f74177b02321&fccid=3d1da8605b3b05a1&vjs=3
# title = Du - Malmö - Indeed.com
#
#
# /rc/clk?jk=1dab40241d0825fa&fccid=4390b8875bb81a53&vjs=3
# title = (Senior) Game Developer - Stockholm - Indeed.com
#
#
# /rc/clk?jk=4195f606079e0260&fccid=9cf2768d0042875a&vjs=3
# title = Online Programmer - 211 22 Malmö - Indeed.com
# https://se.indeed.com/jobs?q=backend&l=sweden&start=610
# 62
#
#
# /rc/clk?jk=8595702852eae7bc&fccid=f8b265243da9f9d7&vjs=3
# title = Backend utvecklare Kotlin, Python - Zynka Digital Buildings Gbg - Göteborg - Indeed.com
# im in
#
#
# /rc/clk?jk=7a496a8d7b1a2e5a&fccid=b20a462c58961ed0&vjs=3
# title = Android Developer - Consider & Contact - 111 21 Stockholm - Indeed.com
#
#
# /rc/clk?jk=14a4fb1dbcac9c49&fccid=23da706355bae1fb&vjs=3
# title = Java developer focusing on new services for Tietoevry... - 111 20 Stockholm - Indeed.com
#
#
# /rc/clk?jk=fea555eb01af3a93&fccid=e668dd67dcce6a2d&vjs=3
# title = Backend C# Engineer - 411 16 Göteborg - Indeed.com
# im in
#
#
# /rc/clk?jk=07f2e711ff36c832&fccid=75437bdf8aac22cf&vjs=3
# title = Developer - 582 22 Linköping - Indeed.com
#
#
# /rc/clk?jk=6184c7e0b92d7bf9&fccid=33619ea9489e1838&vjs=3
# title = React Native Developer - 113 56 Stockholm - Indeed.com
#
#
# /rc/clk?jk=0904f7800550824b&fccid=1dc3423de3cfdec3&vjs=3
# title = Sileo Kapital söker systemutvecklare som vill arbeta i... - 411 19 Göteborg - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0Bc0Iy0UezMNLy7ePkQwjKR0NG1g-De37p3-sR1QbCLdu5j_0vYfv_MM1U0ZzLYpANfOm2_8ZdImA6g_Ppel020lodG7dRTwMmJ1D6IhTCr06Obi8Yt-CCYX3eqGNAbmtMcSc6UCA-XTNB2ZLtQFxiAo2TercJ596tOI67-JpdinaLMSRB8HIkKO8nENteCMm4FALRydUaPpfW5HYoAhGk3NsMp-K3l_so7qOACgqx73QOByfuBtGGGYCMsGCnQHuEv6DMmasbVwTN98Mpy_DSbXJSDIkIqR6DvrNKTgedA8Gi1_QjKTZHamNJhKY93egjK455G4ESHc0JFnkSwCrjQVswThF-P8g-MdtnsyjhFi9wp-_ex3WvdILmLiTOVnpgH4eDBp6x4wp3AbJk1TO4CThVvmqWJlakSILtjMP0XVduA5pC0AkH9x7Nf4x3GutNX6V9IviE1t0LzA_nyy8nJPnEHqd1VBFX2P8-vlEH0uOdkeEowTwZtVbgQz5XM90qF6ZSlJ85dtYa06VUhojuIEK-_SphAlT9Y1AIga3Fp4RGOdtqzsGSS7_A2TfBHQJwOS3tJ4w_nbeAaf_6Wqptj8UOHCmBUh8462Lo_liyKjtTZLwI3-1c6IYur6t9C9lyDf1r0N7ZLz7YgvDmNaBKavCrtBlcX3OXD_5QpKDN8nZ2ReHo3Urn1GMWY10Mzmu4=&p=7&fvj=0&vjs=3
# title = Nyexad Systemutvecklare / Software Developer / Backend till TietoEVRY - Karlstad - Indeed.com
# im in
#
#
# /rc/clk?jk=c46f027c8dde6aab&fccid=9efb9535a1ed71e4&vjs=3
# title = Frontend developer Diagnostic Tool Chain - Södertälje - Indeed.com
#
#
# /rc/clk?jk=897d29f85f8695d7&fccid=2b1ec25fd2cbaa98&vjs=3
# title = iOS Developer - Göteborg - Indeed.com
#
#
# /rc/clk?jk=e50603f13571ba29&fccid=f76e6a86ef7805cd&vjs=3
# title = Mobile Frontend Engineer (React Native) - 113 56 Stockholm - Indeed.com
#
#
# /rc/clk?jk=cf3e2d27a06ed6f8&fccid=0724ac049d2b292c&vjs=3
# title = Data Engineer - 118 27 Stockholm - Indeed.com
#
#
# /rc/clk?jk=0efe64e3caee608e&fccid=deef71adfbe8853a&vjs=3
# title = SCRUM MASTER - Malmö - Indeed.com
#
#
# /rc/clk?jk=3d5f6c87fc83e0ab&fccid=4ac672a7cd45536d&vjs=3
# title = Vi söker! Data scientist with a strong academic background in Machine Learning - 412 58 Göteborg - Indeed.com
#
#
# /rc/clk?jk=a18f8ff31ea9f964&fccid=fe404d18bb9eef1e&vjs=3
# title = Senior Engineering Manager - Stockholm - Indeed.com
# https://se.indeed.com/jobs?q=backend&l=sweden&start=620
# 63
#
#
# /rc/clk?jk=94e131b075dd47af&fccid=50276b1506fc5516&vjs=3
# title = Senior fullstackutvecklare och kompetensankare - Stockholm - Indeed.com
#
#
# /rc/clk?jk=af311dc286aeae7a&fccid=6d33db582c4c6a42&vjs=3
# title = Backend Developer - Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=95fbe9d848eeb55e&fccid=dd616958bd9ddc12&vjs=3
# title = Vitala - mobile developer (React Native) - 907 29 Umeå - Indeed.com
#
#
# /company/Ecommatrix-AB/jobs/Fullstack-Javascript-Developer-acfe05d1fbfd0bfc?fccid=f28d8cc63d41fc9e&vjs=3
# title = FULLSTACK JAVASCRIPT DEVELOPER - Stockholm - Indeed.com
#
#
# /rc/clk?jk=d8580ec2e318fb4a&fccid=935e4694033cc269&vjs=3
# title = JavaScript-utvecklare - 211 19 Malmö - Indeed.com
#
#
# /rc/clk?jk=96c7244cf2da6221&fccid=09381da435d8328c&vjs=3
# title = Pan-Nordic Head of Data & Analytics - Sverige - Indeed.com
#
#
# /rc/clk?jk=812e20eb46ca0424&fccid=dccca727bf1a6346&vjs=3
# title = WordPress-frontend/designer till Etendo - Stockholm - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0B2WYB5nUIf-nu8IexjBrTCOI-EIfgJEpLl-C_Vi97ErftAXPNx-epAvB1zkxmaGTHMTz0z8Xo-3MFuFcqP-UIysk2N1muSYMc9xplsZEnv9E2DTxpwi4s2acH5Y1rDnfIHXgZc7P1b9ZVH9aSBxKVZu2cdKNLneQs_4dvv0-aLfldtXTWI6QlFX0dbX6ofGKCAU8CIldwUsZe_FtGwxtodiXRHc7OiyoybJfaHcOmHlW1hs0OF-IKelUvs0cSjIWi3gLpFil4ANDi_DpoQEiKCakp5D3mn8ufuR82d_75kcxFNTPTM2Ch8OisDlvkx0YdaUXEJOj0SJaKObChPBW8TA8Gqh_xvRf0HggutLg5G2bewCA4NIwY8-WchKwnoO-J9UCCKpomYkpyl72PFmftGRXjtztPlIEEyzv58_1a5sQ9o4Y6nT6BpibtP5z0Q-dB0ROwrHpjsGd8FJT8klei92jQA1WXg4ow=&p=7&fvj=0&vjs=3
# title = Fullstack Developer looking for their next challange - Stockholm - Indeed.com
#
#
# /rc/clk?jk=7d951374840ba153&fccid=23da706355bae1fb&vjs=3
# title = Utvecklare till samhällsnyttiga projekt - 652 26 Karlstad - Indeed.com
#
#
# /rc/clk?jk=4ca33d725c6bbd20&fccid=3e24dd0731ba58b3&vjs=3
# title = Java Developer - Fintech - Fully Remote (Swedish Speaking) - Västerås - Indeed.com
#
#
# /rc/clk?jk=d84ffcf739d2ed09&fccid=d224ef43689d6e3b&vjs=3
# title = C#/.NET - Backend lead developer - 111 44 Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=62199ebfa029643e&fccid=639bee6393c60c73&vjs=3
# title = Electrical Engineer - 417 05 Göteborg - Indeed.com
#
#
# /rc/clk?jk=91f3a8f27c9900cd&fccid=a71f63892a265108&vjs=3
# title = Systemutvecklare till snabbväxande Health-Tech Startup - Stockholm - Indeed.com
#
#
# /rc/clk?jk=f459fb9a579a3db8&fccid=2bcb74f46843a3b9&vjs=3
# title = Senior Financial Consultant – NetSuite - Sverige - Indeed.com
#
#
# /rc/clk?jk=b841a3efc29c3c9c&fccid=505a9f8310876030&vjs=3
# title = Junior mjukvaruutvecklare till talangprogram på Aurobay! - 411 01 Göteborg - Indeed.com
# https://se.indeed.com/jobs?q=backend&l=sweden&start=630
# 64
#
#
# /rc/clk?jk=b841a3efc29c3c9c&fccid=505a9f8310876030&vjs=3
# title = Junior mjukvaruutvecklare till talangprogram på Aurobay! - 411 01 Göteborg - Indeed.com
#
#
# /rc/clk?jk=2169ca41a38278c6&fccid=4ce81a9df94cdf12&vjs=3
# title = Developer - Varberg - Indeed.com
#
#
# /rc/clk?jk=cc9c601a60c06aa8&fccid=f165aeee8966fde9&vjs=3
# title = Webbutvecklare med intresse för e-handel! - Stockholm - Indeed.com
#
#
# /rc/clk?jk=8cd6c96c984cc071&fccid=f68650b8cc8d57cc&vjs=3
# title = Software Engineer to TechHub in Västerås - 111 52 Stockholm - Indeed.com
#
#
# /rc/clk?jk=5272fff59f91877a&fccid=e4f6a64b6ba43cf5&vjs=3
# title = Senior Full-Stack Developer - 111 52 Stockholm - Indeed.com
#
#
# /rc/clk?jk=cd5777ead209a11e&fccid=b2af14108c40f46f&vjs=3
# title = Senior Backend Developer - 111 53 Stockholm - Indeed.com
# im in
#
#
# /rc/clk?jk=0cf3c6ca7907ef67&fccid=00cb96e3f3922560&vjs=3
# title = Senior BI Developer - Stockholm - Indeed.com
#
#
# /rc/clk?jk=5644aa5e44547bca&fccid=b276df3fa16c132a&vjs=3
# title = Senior Software Developer - Göteborg - Indeed.com
#
#
# /rc/clk?jk=e2837790fb5a9cc6&fccid=de5f16ecf49850af&vjs=3
# title = Systemutvecklare - Stockholm - Indeed.com
#
#
# /rc/clk?jk=e45f9e6758e6a229&fccid=210664c7804749b6&vjs=3
# title = Software Engineer Frontend - 111 52 Stockholm - Indeed.com
#
#
# /rc/clk?jk=b0368129eb6c4e15&fccid=d8b31ed599b53064&vjs=3
# title = Back End Software Engineer - Distributed Order Management team - Stockholm - Indeed.com
#
#
# /company/Spendrups-Bryggeri-AB/jobs/Systemutvecklare-ac749e11534de25a?fccid=090580e0b80e19bc&vjs=3
# title = Systemutvecklare - 143 03 Vårby - Indeed.com
#
#
# /rc/clk?jk=135336e148dc5bdd&fccid=23da706355bae1fb&vjs=3
# title = Java-utvecklare - 753 18 Uppsala - Indeed.com
#
#
# /rc/clk?jk=7e191adb938d66f1&fccid=b18eaf59eb3dea36&vjs=3
# title = Fullstack Developer - 113 53 Stockholm - Indeed.com
#
#
# /rc/clk?jk=77f3c186dccd91c0&fccid=d487b550496b26ff&vjs=3
# title = Middle QA Engineer to scale up - 114 27 Stockholm - Indeed.com
# https://se.indeed.com/jobs?q=backend&l=sweden&start=640
# 65
#
#
# /rc/clk?jk=95131a71b41be6e9&fccid=94455b3693f53981&vjs=3
# title = Skicklig .NET utvecklare - Örebro - Indeed.com
#
#
# /rc/clk?jk=dd4450a3b1132e38&fccid=984f639782e0a262&vjs=3
# title = Full Stack Developer - Linköping - Indeed.com
#
#
# /rc/clk?jk=f1a2a9e52316232b&fccid=c6b1615bdb69ef32&vjs=3
# title = Frontend Developer - 211 19 Malmö - Indeed.com
#
#
# /rc/clk?jk=c535f581f78b6074&fccid=edc14277fa132243&vjs=3
# title = Software Development - Lead Application Manager - Trollhättan - Indeed.com
#
#
# /rc/clk?jk=e2711357ab2e42eb&fccid=b876a8e16c929182&vjs=3
# title = Lead Mobile Engineer - 111 21 Stockholm - Indeed.com
#
#
# /rc/clk?jk=513c282f97b2cfad&fccid=08405ccc2b4b4362&vjs=3
# title = Streaming Software Engineer - 411 37 Göteborg - Indeed.com
#
#
# /rc/clk?jk=e9e8d342c1167a45&fccid=639bee6393c60c73&vjs=3
# title = QA Software Engineer - 417 05 Göteborg - Indeed.com
#
#
# /rc/clk?jk=fc71141dd37695ae&fccid=21e522419cad8a4d&vjs=3
# title = Sales Engineer - 114 26 Stockholm - Indeed.com
#
#
# /rc/clk?jk=b64a2245786733b1&fccid=c5d6744288ce9849&vjs=3
# title = Full Stack Developer - 111 44 Stockholm - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0B2WYB5nUIf-nu8IexjBrTCOI-EIfgJEpLl-C_Vi97ErftAXPNx-epAvB1zkxmaGTEZBtxzWjbzdB9j1-BI3R2SfQF-Vo1qDvFTySU-oZmWhcHtQeBQQm_mH0yxkdGf8ZdCFIRYSpeVcDuGfFlxTvNAlhPUhtad8qMoZnSCDWPa3wpPZG5a3Dh7_uv3e1ioR9UAd7eZgI_awPNP_2L6cfVQz1UADFAt1bgA-BuoPiUJpyGaho89eRUN68uZhCxutJ_PJvDtjYo9ldRDhlMhJ1flHKE5Q5esxkMFfbe6oYdtxASCvHiZf2fw0bpUnRhaNKjH-1xthC79fW2Oa9Uqm8n20jeja6V5VnXQLq-Bauwq3P13q_XvqNy1ovy1b01-ayKZq86MPjzwLIvctACJIza24IoOwTE-hAZm7U7u20Wyk1O0gubm_kcuYAt5EKOcELEGnyjewsqQGk7ebKW70jVV&p=9&fvj=0&vjs=3
# title = Full-Stack Developer (React/Go) - Payments - Stockholm - Indeed.com
#
#
# /rc/clk?jk=e9155dbbeebf379d&fccid=1eb24ab9524f4919&vjs=3
# title = Erfaren backendutvecklare med intresse för systemarkitektur - Göteborg - Indeed.com
# im in
#
#
# /rc/clk?jk=8d1e159cf2ff1169&fccid=5bed0b5dcbf1bc17&vjs=3
# title = Engineering Manager - Calling - Stockholm - Indeed.com
#
#
# /rc/clk?jk=78ba90c22fad06b3&fccid=e668dd67dcce6a2d&vjs=3
# title = JAVA Developer - 111 29 Stockholm - Indeed.com
#
#
# /rc/clk?jk=b13022b5441612a8&fccid=97866fc62687e2ba&vjs=3
# title = Fullstack Utvecklare - Stockholm - Indeed.com
#
#
# /rc/clk?jk=8baf90816ec825ef&fccid=b276df3fa16c132a&vjs=3
# title = Full Stack Engineer - Göteborg - Indeed.com
# https://se.indeed.com/jobs?q=backend&l=sweden&start=650
# 66
#
#
# /rc/clk?jk=8baf90816ec825ef&fccid=b276df3fa16c132a&vjs=3
# title = Full Stack Engineer - Göteborg - Indeed.com
#
#
# /rc/clk?jk=53006c3a9a4da4a9&fccid=7196718d4df27c86&vjs=3
# title = iOS Developer - 118 26 Stockholm - Indeed.com
#
#
# /rc/clk?jk=e94eb40434cf6e43&fccid=6c4f4b4cdc28efb5&vjs=3
# title = Azure Developer - 760 49 Herräng - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0Dlz06xAeb47oNpufS0JEnbCgZ8nT4CDUEuPQuvPbpp1Pby5_PhLtvvBw1x_5Oat3-5OeAZ9WWRz5t9en1xIJMiLSYv6Cg_ah31rD6vj0NG5q9N8bXl0h3Ssd0K_1bL4QGgPYwptkbr3iiyGjoqvnMm-lm1S5btqCw-GsnfDYE2-HBw8Y_P7Z71cUYjr0KwNzAtYvOiYcYrW-i9WD7U5kt0ObtkvgTXRbnokiez3j3FzMqstYL81VbaofxVc2VJDXw4NafPFyGeAj4AE4PFp8nEP2pUUHGV0WMSCtpSEzWRGqa03bdISg5Z4khqSgrf48u3ve6XZFpBpLNHrvh-MglBEhqLNsJjSIXDdphdt0g6EaHrcbFVJOf7O3qnOMTtRgYPrXy9N25Bg4P197xy1OyUwjxFdIfECPyUnMKI9dxgNPdgKyR_fObeLlb7u-3D0JIChcGwmnJE3vAftF8OS3MPobBs1qkIaNiFWjXqY30S2zGxrRPUsV2_IAkWxQgANOhC-nJjCIriq2OyvARKYr1DwfnXIEf6Kb9QgbcjpMmjeanc8eMlP8_2YSF-sVVfw3ZCIcTcqukSfTA4F4EHFzXKT_LYl5oPo7mgqN5ituYQNHI2A9_GtvIxEa9-M4gLo05o0Ap7XoYLzM3txWeRsOEFyz65x8uze_IuFL7iel6Ga5kt4ZGiz4FrBsHW-gfuor4VhYF5m3geyJEldTMWFQiBPNqykhohKtQ=&p=3&fvj=0&vjs=3
# title = Senior iOS Software Engineer - Stockholm - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0D9xrLoAM8osgDm547torDhdSLyyZjm4c4M1v28Gizw8n1rL3FrumFJ6xsZaaz1udLfP8kiTlY1qVuayK4RaUpoZBwt2ifvbBF-iOPXATShw6RVmGpKapvGM2ITvi38e89hqi9fmlQKs8xEw6crywvZ3wvybFTT-v9FBpVRVtg8uOlbDxxlBtGjHb1w8VG33AQfZVpVKiMTwkE97E_r9Q6la_o-chFk1erYEvXqwMGZEtmy1B_IZdD7r14eR8y0b4e0ofaF9Hdvf0ObY4BRvxsk9umOq7z-Mw8ZR8iUS5m_QM-WbIHh1UWnMusta0J1BpiNgI_KaxAhbPYzgjL3jzHtcl7ryMYkBEQZ96BWYREY1YyZTnMNBkUdGfySI8MSMt04SuD9YUt1RpnCMtfttZ9nfX_FU-4OewBF_vRkMksr5zhlr8ZOw558CPOZu4qYtH7o315v82F1AxJdeJnNLtNfcuFXps1hC-XIHcUFOifN3ibu9Jn1N0N557Kc8Noq9Suz-fCf3L74EI5AY5yFEYbBLoGEPeHLZKPwFd4GMBJaxjUoU950cGH7eJog8hYImlj5Y4PkY4dFKpu16M0qHEAS9vRtDr7NimoMc5wS0fxTZ9XlvIRpa0u-tHR-lv8xDmBpFPARVjeqo-qQ06mBtLHYZamWljxtywOJNcP0lzxzjaSpuLJw2p9ad3uLx60IEAjwv4FjGuqKvH4INgNAafbo&p=4&fvj=0&vjs=3
# title = Ledare till vårt Experience Solutions-gäng - Stockholm - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0AXbwWRkNJwq2372GYLd0pY970pZElQAAwGosnC6oHaSx7SJWJmQhzcxmEMjAjdA2Pk3qRz5WAyGsv8RCg-k8UHHCGFcrUoLz3k1MIvbug13TCXRxR8yh-W-2oMNDQJ3Oz_b27huRkS-LXaq8jZAERP0sVSjVigkI51Agf5q7ornPdan9Gzollo-GCy8Iof2xBIIqrHQBwVk6iKRybCOQhXAV0d8EH7NJsN1wziV1X0h4O9qO-WcH5t6w6EbhsIudm9MwW4CjGkDRKdz76reywWAV8j7k5qIpvujkSEysBAUsHh1UmhhYOJ0lyh6zSuy7lpHOQ6SHdsey1TiAzN90OGGHahsJ9ctTKT4ormrwnTxYO01xcEOqoKX4T0DLuqzrzYOwL5Yd7gsiB9ZQ6jdIYlQTGgY5m362egYBBpnRqU1bh9bIfsceeYFiUlhJ2ZQlaBIRm00JS8zKtTNgA8DyFjm6i6Fl0A9i49K0y7_odEn6PthPYzMjYH30o3KZD-svj3jrfhXemqCUaF1Dcuaf_msrCzZ-vYreJzg-eamxwzg85VTNn6aRl72Qz_HuVVEa2froDweeU5IEeaSwwDc4a9uq-2D4gXyr6kq-Yw0V4usf_ciZrQXKiY0KRQoAOwNTIjyFitRCCzFQ==&p=5&fvj=0&vjs=3
# title = Erfaren Fullstack Engineer - Göteborg - Indeed.com
#
#
# /pagead/clk?mo=r&ad=-6NYlbfkN0B2WYB5nUIf-nu8IexjBrTCOI-EIfgJEpLl-C_Vi97ErftAXPNx-epAvB1zkxmaGTFT1aKIgiONPX-XJOeu9qFgm3Ej2UyFMZ-MUl7yQRBHjV6dzkIVj1GQ2Uz1TzJyHDZsZt7uBIxqTeEqqjoj-by831IwAtasC_BaRV8btSVXVFZ3kPrDPwmFIqeoWcNf_9IQ4ioAVL7KJhbYk2OHF8L8_KLAmkzAc50BKjojzVbUvQzIxTySy8cCrBiyBVvfHA2V39eHSdw3RQpGXFwnI31RwPjZdNf1-Sr3LjwGuWp6UiJ72FuCLIsDVFsOnKwUXGamSw1ghfwWNI1WuXrlbpSY3hICLn_w8fZ3zaDUuD_fxsFIQN46aJ-P_iWZ421a1X-eDkNifA9Tm0S_gvEVa0Ad97sjn6ISm9SpHdw8XPaB2AFky13Hx-A2B8ucSvT39kYkJSKWHULk5w==&p=6&fvj=0&vjs=3
# title = Senior Backend Engineer - Stockholm - Indeed.com
# im in
# <class 'AttributeError'>

# %% [markdown]
# ### Explanation

# %%
front_page_url =get_url('backend', 'sweden',1)
front_page_response = requests.get(front_page_url)
all_html = BeautifulSoup(front_page_response.text, 'html.parser')

# %%
all_html
# Out:
# <html lang="en">
# <head>
# <title>hCaptcha solve page</title>
# <script async="" defer="" src="https://www.hcaptcha.com/1/api.js"></script>
# </head>
# <body>
# <form action="/jobs?q=backend&amp;l=sweden&amp;start=0" method="POST">
# <div class="h-captcha" data-sitekey="eb27f525-f936-43b4-91e2-95a426d4a8bd"></div>
# <br/>
# <input type="submit" value="Submit"/>
# </form>
# </body>
# </html>

# %%
all_html.find_all('a',{'class':"jcs-JobTitle"})
# Out:
# [<a aria-label="all information om Senior Backend Developer - Code With A Purpose" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="93a16f4f2307af1e" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=93a16f4f2307af1e&amp;fccid=7fe31231d8054866&amp;vjs=3" id="job_93a16f4f2307af1e" role="button" target="_blank"><span title="Senior Backend Developer - Code With A Purpose">Senior Backend Developer - Code With A Purpose</span></a>,
#  <a aria-label="all information om Knowit Experience Traineeprogram 2022 – Utvecklare" class="jcs-JobTitle" data-ci="367488318" data-empn="6681184386882833" data-hide-spinner="true" data-hiring-event="false" data-jk="4b37bbe1bb69059f" data-mobtk="1g2lcmtjmj9h0800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AXbwWRkNJwq2372GYLd0pY970pZElQAAwGosnC6oHaSx7SJWJmQhzcxmEMjAjdA2N8IIaww9ZU9-pEOHyX-DiQKlyg5jpYxY1obHEXoBJdbnxiacWe65JA2TQh34FdiIxpfT-N9wsFIVsoLUPkwjGOSTlgJ2HXLNZGjr5DUGA5hipxYoJqdVBDLI-A23T4y72AkzibAp3amnUEf-MpzD2ogU0z-outNYRJ3FqCEhLcRIYQwBmkZ9S3z1U7_07ALP0vmglxkd1ls-6lnIsBmpf9BC6SeL6Coj168RFK4ZpMPBWftPhUX6Ut_mZw3uAW5Lm7O1xEaYIWQepk3URt_IN5mTIj9yLiJ_i7UL8mHQ9jDuEcIFt7xH_fizSFkMAR2O3Wtp_eUQsC4703CzceUFQaPNTobABnsVtLA6_oryt2Lxq1fK7xbfp6TeAearFkunflGTMiBoLwal_e2Qsi9aU6MMrB_766zh_hn7x74tA03r5mcsV7CVo6Aw8HaDoF2BwZTXNRvO2tSGBkLXno2FC9U2U4xbFqbf3GP0JYVoMj4Y7mrHxVebxuleDr-F_agqxNJWtFTKr_JoJMWRHL2dVt5BdodRtUcsntky5_KBqLXNFyRgqVxI74y7IO6W7azRNZxqZOwKxjL8mq0AuPupNuwPH5zLq4WTvB1PaHEXSNQg==&amp;p=1&amp;fvj=0&amp;vjs=3" id="sj_4b37bbe1bb69059f" role="button" target="_blank"><span title="Knowit Experience Traineeprogram 2022 – Utvecklare">Knowit Experience Traineeprogram 2022 – Utvecklare</span></a>,
#  <a aria-label="all information om Backend Engineer, Freemium" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="c3baec7be8eb099e" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=c3baec7be8eb099e&amp;fccid=fe404d18bb9eef1e&amp;vjs=3" id="job_c3baec7be8eb099e" role="button" target="_blank"><span title="Backend Engineer, Freemium">Backend Engineer, Freemium</span></a>,
#  <a aria-label="all information om Backend Developer" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="c2267ca1b1bfee8f" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=c2267ca1b1bfee8f&amp;fccid=dc23a49366780089&amp;vjs=3" id="job_c2267ca1b1bfee8f" role="button" target="_blank"><span title="Backend Developer">Backend Developer</span></a>,
#  <a aria-label="all information om Backend utvecklare" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="d62ece4b727305ab" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=d62ece4b727305ab&amp;fccid=e4421c5792767e55&amp;vjs=3" id="job_d62ece4b727305ab" role="button" target="_blank"><span title="Backend utvecklare">Backend utvecklare</span></a>,
#  <a aria-label="all information om Software Engineers for Business Strategy, Data, Analytics, S..." class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="8b7cccc2a8f5c5c9" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=8b7cccc2a8f5c5c9&amp;fccid=af17ea0d1d6bbbba&amp;vjs=3" id="job_8b7cccc2a8f5c5c9" role="button" target="_blank"><span title="Software Engineers for Business Strategy, Data, Analytics, Security, Group Digital">Software Engineers for Business Strategy, Data, Analytics, S...</span></a>,
#  <a aria-label="all information om Backend Engineer, Data Insights" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="b8c10fe11b730530" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=b8c10fe11b730530&amp;fccid=fe404d18bb9eef1e&amp;vjs=3" id="job_b8c10fe11b730530" role="button" target="_blank"><span title="Backend Engineer, Data Insights">Backend Engineer, Data Insights</span></a>,
#  <a aria-label="all information om Junior backend-utvecklare" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="17a468ffff016f73" data-mobtk="1g2lcmtjmj9h0800" href="/company/InfraSight-Labs/jobs/Junior-Backend-Utvecklare-17a468ffff016f73?fccid=61bfd31af9b019a7&amp;vjs=3" id="job_17a468ffff016f73" role="button" target="_blank"><span title="Junior backend-utvecklare">Junior backend-utvecklare</span></a>,
#  <a aria-label="all information om Backend-utvecklare" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="8be8c1f1ca27991e" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=8be8c1f1ca27991e&amp;fccid=9d5e940e504c7fa2&amp;vjs=3" id="job_8be8c1f1ca27991e" role="button" target="_blank"><span title="Backend-utvecklare">Backend-utvecklare</span></a>,
#  <a aria-label="all information om Backend Engineer, Audiobooks &amp; Gated Content" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="8f85dbe6711ee0e9" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=8f85dbe6711ee0e9&amp;fccid=fe404d18bb9eef1e&amp;vjs=3" id="job_8f85dbe6711ee0e9" role="button" target="_blank"><span title="Backend Engineer, Audiobooks &amp; Gated Content">Backend Engineer, Audiobooks &amp; Gated Content</span></a>,
#  <a aria-label="all information om Kom och arbeta i molnet med oss!" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="fc883433f9e2e383" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=fc883433f9e2e383&amp;fccid=c4231f13692d1515&amp;vjs=3" id="job_fc883433f9e2e383" role="button" target="_blank"><span title="Kom och arbeta i molnet med oss!">Kom och arbeta i molnet med oss!</span></a>,
#  <a aria-label="all information om Vill du vara med och utveckla framtidens produkter?" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="d804f7bfc62c7221" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=d804f7bfc62c7221&amp;fccid=a648801f049f03f9&amp;vjs=3" id="job_d804f7bfc62c7221" role="button" target="_blank"><span title="Vill du vara med och utveckla framtidens produkter?">Vill du vara med och utveckla framtidens produkter?</span></a>,
#  <a aria-label="all information om Backend Developer" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="3812f098308561aa" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=3812f098308561aa&amp;fccid=c75ecafa2f53609d&amp;vjs=3" id="job_3812f098308561aa" role="button" target="_blank"><span title="Backend Developer">Backend Developer</span></a>,
#  <a aria-label="all information om Summer Worker Web Development (Steam)" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="8424ab91bcba2f60" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=8424ab91bcba2f60&amp;fccid=edae4285faf6c2f0&amp;vjs=3" id="job_8424ab91bcba2f60" role="button" target="_blank"><span title="Summer Worker Web Development (Steam)">Summer Worker Web Development (Steam)</span></a>,
#  <a aria-label="all information om Backend - Utvecklare" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="075e5a4a83ee836f" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=075e5a4a83ee836f&amp;fccid=b2b4e7a4f97d8481&amp;vjs=3" id="job_075e5a4a83ee836f" role="button" target="_blank"><span title="Backend - Utvecklare">Backend - Utvecklare</span></a>]

# %%
all_html.find_all('a',{'class':"jcs-JobTitle", 'id':"job_93a16f4f2307af1e"})
# Out:
# [<a aria-label="all information om Senior Backend Developer - Code With A Purpose" class="jcs-JobTitle" data-hide-spinner="true" data-hiring-event="false" data-jk="93a16f4f2307af1e" data-mobtk="1g2lcmtjmj9h0800" href="/rc/clk?jk=93a16f4f2307af1e&amp;fccid=7fe31231d8054866&amp;vjs=3" id="job_93a16f4f2307af1e" role="button" target="_blank"><span title="Senior Backend Developer - Code With A Purpose">Senior Backend Developer - Code With A Purpose</span></a>]

# %%
import pandas as pd

#Specific NLP imports
from scipy.stats import hmean
import scattertext as st
import requests     
stopwords_list = requests.get("https://gist.githubusercontent.com/rg089/35e00abf8941d72d419224cfd5b5925d/raw/12d899b70156fd0041fa9778d657330b024b959c/stopwords.txt").content
global stopwords 
stopwords = set(stopwords_list.decode().splitlines()) 
special_words = ['ml','ci','cd']
for word in special_words:
    stopwords.remove(word)

#Regex for text processing
import re
def remove_special_characters(word_list,remove_stop_words = True):
    global stopwords
    res = re.findall('(?!_)\w+(?<!_)', word_list.lower())
    if remove_stop_words == True:
        no_stop_words = [word for word in res if word not in stopwords]
        res = " ".join(no_stop_words)
    else:
        with_stop_words = [word for word in res]
        res = " ".join(with_stop_words)
    return res
def csv_string_list_to_df_list(csv_list,drop_duplicates=True,drop_rows_to_lowest = True):
    """Reads csv files and converts to a list of data frame for each file(role).
    Args:
        text (str): .csv file names including .csv   (e.g. data_scientist.csv)
    Returns:
        list of pandas.DataFrame: representing each category. 
    """
    
    #Read csv file and prune it. Repeat for all csv files.
    df_list = []
    for csv in csv_list:
        category_df = pd.read_csv(csv)         #Reads csv file
        category_name = csv.split('.')[0]      #The category gets named based on file name. fullstack.csv => fullstack
        category_df['title'] = [category_name]*len(category_df) #continuation of above line
        category_df.dropna(subset=['requirements'],inplace=True)          #drop rows with null
        category_df = category_df[category_df['title'] != 'title']        #drops the stamp created in csv making
        if drop_duplicates == True:
            category_df =  category_df[category_df.groupby(['title','requirements']).cumcount().le(0)] #remove duplicates
            #category_df.drop_duplicates(subset=['requirements'],inplace=True) 
        df_list.append(category_df)  
    
    #To remove participation bias, all roles should have the same amount of data.
    #Cut down rows so that all roles have the same rows as the role with the lowest amount of rows.
    if drop_rows_to_lowest == True:
        lowest_len = len(df_list[0])         
        for df in df_list:                   
            if lowest_len > len(df):
                lowest_len = len(df)
        df_list = list(map(lambda x: x[:lowest_len],df_list))    
    
    
    #Add the column to be parsed. requirements column will be used for the model.
    new_df =[]
    for df in df_list:                 
        df['parsed'] =df['requirements'].apply(remove_special_characters)     
        #df['parsed'] =df['parsed'].apply(ss.stem)       #stemming could be added
        df['parsed'] =df['parsed'].apply(st.whitespace_nlp_with_sentences)   #NLP Tokenizing 
        df = df[['title','parsed']]      #Drop every other column to get correct format.
        new_df.append(df)
    return new_df

# %%
x =csv_string_list_to_df_list(['frontend_2022-05-13.csv'])

# %%
x[0]
# Out:
#                    title                                             parsed
# 0    frontend_2022-05-13  (har, minst, 3, års, erfarenhet, frontend, utv...
# 1    frontend_2022-05-13  (erfarenhet, react, ett, bra, öga, för, design...
# 2    frontend_2022-05-13  (arbeta, med, nyutveckling, javascript, samt, ...
# 3    frontend_2022-05-13  (javascript, react, kan, skapa, engagerande, d...
# 4    frontend_2022-05-13  (tjänst, frontend, utvecklaretjänstgöringsgrad...
# ..                   ...                                                ...
# 187  frontend_2022-05-13  (minst, 3, års, erfarenhet, ramverk, angular, ...
# 188  frontend_2022-05-13  (att, tillsammans, med, teamet, följa, våra, u...
# 189  frontend_2022-05-13  (payments, people, save, time, waiting, automa...
# 191  frontend_2022-05-13  (tjänst, på, ett, familjärt, och, entreprenörs...
# 193  frontend_2022-05-13  (improve, app, quality, build, house, develope...
#
# [173 rows x 2 columns]
